# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## PRACTICA OBLIGATORIA: **Visualización Básica**

# %% [markdown]
# * La práctica obligatoria de esta unidad consiste en un único ejercicio de construcción de gráficas. Descarga este notebook en tu ordenador y trabaja en local. Ten en cuenta que tendrás que descar los directorios de imágenes y datos adicionales, si los hubiera.
# * Recuerda que debes subirla a tu repositorio personal antes de la sesión en vivo para que puntúe adecuadamente.
# * Recuerda también que no es necesario que esté perfecta, sólo es necesario que se vea el esfuerzo.
# * Esta práctica se resolverá en la sesión en vivo correspondiente y la solución se publicará en el repo del curso.

# %% [markdown]
# ### Ejercicio 0

# %% [markdown]
# Importa los paquetes y módulos que necesites a lo largo del notebook.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Ejercicio 1

# %% [markdown]
# #### #1.1
#
# - Carga el dataset de casas de California que está en la ruta "./data/california_cities.csv".
# - Muestra parte de su contenido y su descripción.
# - Deshazte de las filas con nulos.

# %%
# #1.1 

# 1. Carga el dataset de casas de California que está en la ruta "./data/california_cities.csv"
df = pd.read_csv("./data/california_cities.csv")

# 2. Muestra parte de su contenido (primeras filas)
print("--- Primeras filas del dataset ---")
display(df.head())

# Muestra su descripción (estadísticas principales)
print("\n--- Descripción estadística ---")
display(df.describe())

# 3. Deshazte de las filas con nulos
# Comprobamos cuántos nulos hay antes (opcional pero recomendado)
print(f"\nValores nulos antes de limpiar: {df.isnull().sum()}")
# Out:
# --- Primeras filas del dataset ---
#    Unnamed: 0         city       latd       longd  elevation_m  elevation_ft  \
# 0           0     Adelanto  34.576111 -117.432778        875.0        2871.0
# 1           1  AgouraHills  34.153333 -118.761667        281.0         922.0
# 2           2      Alameda  37.756111 -122.274444          NaN          33.0
# 3           3       Albany  37.886944 -122.297778          NaN          43.0
# 4           4     Alhambra  34.081944 -118.135000        150.0         492.0
#
#    population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0             31765            56.027           56.009             0.018
# 1             20330             7.822            7.793             0.029
# 2             75467            22.960           10.611            12.349
# 3             18969             5.465            1.788             3.677
# 4             83089             7.632            7.631             0.001
#
# ...

# %%
df.dropna(inplace=True)  # Busca cualquier fila que contenga al menos un valor vacío (NaN) y la elimina por completo del DataFrame

# Comprobamos después
print(f"Valores nulos después de limpiar: {df.isnull().sum()}")
# Out:
# Valores nulos después de limpiar: Unnamed: 0            0
# city                  0
# latd                  0
# longd                 0
# elevation_m           0
# elevation_ft          0
# population_total      0
# area_total_sq_mi      0
# area_land_sq_mi       0
# area_water_sq_mi      0
# area_total_km2        0
# area_land_km2         0
# area_water_km2        0
# area_water_percent    0
# dtype: int64

# %% [markdown]
# #### #1.2
#
# Recrea la siguiente figura, para ello construye en apartados separados cada gráfico y luego haz un apartado en el que se junten los cuatro.
#
# Las figuras son:
# 1. Las ciudades más pobladas, con los numeros de las poblaciones (tendrás que usar texto y recordar que para centrarlos se necesita poner el argumento `ha` a "center" o investigar como funciona bar_label). Los colores de las barras deben tener un 50% de transparencia y ser: azul, gris, rojo, aceituna y marrón.
#
# 2. Histograma del área total ocupada por las ciudades. (50 bins, fuente = "Arial", tamaño = 14, peso = "Bold", color azul acero o "steelblue")
# 3. El scatter de área de agua de un ciudad con su poblacion. Transparencia al 50% y color verde.
# 4. El boxplot de la altura de las ciudades.

# %% [markdown]
# ![practica_obligatoria.png](attachment:4b308c10-50de-4eaf-a370-6850ae2996a8.png)

# %%
# 1. Preparación de datos
df_copy = df.copy()
# Convertimos población a miles para que coincida con los ejes de la imagen
df_copy['pop_thousands'] = df_copy['population_total'] / 1000

# Top 5 para el gráfico de barras
top_5 = df_copy.sort_values("population_total", ascending=False).head(5)
colores = ['blue', 'gray', 'red', 'olive', 'brown']

# Crear la figura
fig, ax = plt.subplots(2, 2, figsize=(18, 16))

# --- Gráfico 1: Barras ---
bars = ax[0, 0].bar(top_5['city'], top_5['pop_thousands'], color=colores, alpha=0.5)
ax[0, 0].bar_label(bars, fmt='%.2f', padding=3)
ax[0, 0].set_title("Ciudades más pobladas de California")
ax[0, 0].set_xlabel("Ciudades")
ax[0, 0].set_ylabel("Habitantes (miles)")
ax[0, 0].set_ylim(0, 5000)

# --- Gráfico 2: Histograma ---
ax[0, 1].hist(df_copy['area_total_km2'], bins=50, color='steelblue', alpha=0.7, label='Hist Area')
ax[0, 1].set_title("Histograma del área total ocupada por las ciudades", fontweight='bold')
ax[0, 1].set_xlabel("Superficie ($km^2$)", fontweight='bold', fontsize=12)
ax[0, 1].set_ylabel("Número de Ciudades", fontweight='bold', fontsize=12)
ax[0, 1].legend()

# --- Gráfico 3: Scatter con Anotaciones ---
ax[1, 0].scatter(df_copy['area_water_km2'], df_copy['pop_thousands'], color='green', alpha=0.5)
ax[1, 0].set_title("Población por kilometro cuadrado de agua")
ax[1, 0].set_xlabel("Área de agua en la ciudad ($km^2$)")
ax[1, 0].set_ylabel("Población (miles habitantes)")

# Añadir las flechas de Outliers
# Localizamos los dos puntos más altos (aprox Los Angeles y San Diego)
outliers = df_copy.sort_values("pop_thousands", ascending=False).head(2)

ax[1, 0].annotate('Outliers', xy=(outliers.iloc[0]['area_water_km2'], outliers.iloc[0]['pop_thousands']),
             xytext=(60, 3000), arrowprops=dict(arrowstyle='->', color='black'))

ax[1, 0].annotate('', xy=(outliers.iloc[1]['area_water_km2'], outliers.iloc[1]['pop_thousands']),
             xytext=(65, 2950), arrowprops=dict(arrowstyle='->', color='black'))

# --- Gráfico 4: Boxplot ---
ax[1, 1].boxplot(df_copy['elevation_m'], vert=False, patch_artist=True, 
                 boxprops=dict(facecolor='red'))
ax[1, 1].set_title("Diagrama de caja de la Altitud de las ciudades de California")
ax[1, 1].set_xlabel("Altitud (m)")
ax[1, 1].set_yticks([]) # Eliminar el label del eje Y para que luzca igual

plt.tight_layout()
plt.show()

# %% [markdown]
# #### #1.3
#
# Graba la figura en un archivo .png y sube el archivo a tu repositorio personal junto con el notebook.

# %%
# 1. Preparación de datos
df_copy = df.copy()
# Convertimos población a miles para que coincida con los ejes de la imagen
df_copy['pop_thousands'] = df_copy['population_total'] / 1000

# Top 5 para el gráfico de barras
top_5 = df_copy.sort_values("population_total", ascending=False).head(5)
colores = ['blue', 'gray', 'red', 'olive', 'brown']

# Crear la figura
fig, ax = plt.subplots(2, 2, figsize=(18, 16))

# --- Gráfico 1: Barras ---
bars = ax[0, 0].bar(top_5['city'], top_5['pop_thousands'], color=colores, alpha=0.5)
ax[0, 0].bar_label(bars, fmt='%.2f', padding=3)
ax[0, 0].set_title("Ciudades más pobladas de California")
ax[0, 0].set_xlabel("Ciudades")
ax[0, 0].set_ylabel("Habitantes (miles)")
ax[0, 0].set_ylim(0, 5000)

# --- Gráfico 2: Histograma ---
ax[0, 1].hist(df_copy['area_total_km2'], bins=50, color='steelblue', alpha=0.7, label='Hist Area')
ax[0, 1].set_title("Histograma del área total ocupada por las ciudades", fontweight='bold')
ax[0, 1].set_xlabel("Superficie ($km^2$)", fontweight='bold', fontsize=12)
ax[0, 1].set_ylabel("Número de Ciudades", fontweight='bold', fontsize=12)
ax[0, 1].legend()

# --- Gráfico 3: Scatter con Anotaciones ---
ax[1, 0].scatter(df_copy['area_water_km2'], df_copy['pop_thousands'], color='green', alpha=0.5)
ax[1, 0].set_title("Población por kilometro cuadrado de agua")
ax[1, 0].set_xlabel("Área de agua en la ciudad ($km^2$)")
ax[1, 0].set_ylabel("Población (miles habitantes)")

# Añadir las flechas de Outliers
# Localizamos los dos puntos más altos (aprox Los Angeles y San Diego)
outliers = df_copy.sort_values("pop_thousands", ascending=False).head(2)

ax[1, 0].annotate('Outliers', xy=(outliers.iloc[0]['area_water_km2'], outliers.iloc[0]['pop_thousands']),
             xytext=(60, 3000), arrowprops=dict(arrowstyle='->', color='black'))

ax[1, 0].annotate('', xy=(outliers.iloc[1]['area_water_km2'], outliers.iloc[1]['pop_thousands']),
             xytext=(65, 2950), arrowprops=dict(arrowstyle='->', color='black'))

# --- Gráfico 4: Boxplot ---
ax[1, 1].boxplot(df_copy['elevation_m'], vert=False, patch_artist=True, 
                 boxprops=dict(facecolor='red'))
ax[1, 1].set_title("Diagrama de caja de la Altitud de las ciudades de California")
ax[1, 1].set_xlabel("Altitud (m)")
ax[1, 1].set_yticks([]) # Eliminar el label del eje Y para que luzca igual

plt.tight_layout()
# plt.show()

# 1. Guardar la imagen
plt.savefig("mi_grafica_california.png", dpi=300, bbox_inches='tight')

# 2. Mostrar la imagen (siempre después de guardar)
plt.show()
